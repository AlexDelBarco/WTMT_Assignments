# %% [markdown]
# Import pandas and the mysql library

# %%
import pandas as pd
import pymysql.cursors
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Connect to the MySQL database

# %%
db=pymysql.connect(host="data02.windenergy.dtu.dk",user="students",password="H040",charset='utf8')

# %% [markdown]
# Execute the SQL command on the server and load the results in the dataframe. Treat field "name" as a date-time and use this as the index of the dataframe.

# %%
WindData=pd.read_sql("select * from c46400.dataset_as03;",con=db,parse_dates="name",index_col="name")
WindData.describe()
# Out:
# /tmp/ipykernel_22488/3642863314.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   WindData=pd.read_sql("select * from c46400.dataset_as03;",con=db,parse_dates="name",index_col="name")
#        Cup116m_Mean  Cup116m_Stdv   Cup116m_Min   Cup116m_Max  Cup114m_Mean  \
# count  12084.000000  12084.000000  12084.000000  12084.000000  12084.000000
# mean       9.171476      0.667874      7.142197     11.040740      9.688137
# std        4.712528      0.445456      3.670575      5.679712      4.933472
# min        0.000000      0.000000      0.000000      0.000000      0.522059
# 25%        6.133538      0.368242      4.795138      7.366343      6.405145
# 50%        8.697975      0.585182      6.837950     10.397250      8.881545
# 75%       11.468300      0.870433      9.120593     13.776300     11.822550
# ...

# %%
WindData['Cup116m_Mean'].plot(figsize=(18,6),grid=True,ylabel="WS [m/s]")
# Out:
# <Axes: xlabel='name', ylabel='WS [m/s]'>

# %%
WindData['Spd'].plot(figsize=(18,6),grid=True,ylabel="WS [m/s]")
# Out:
# <Axes: xlabel='name', ylabel='WS [m/s]'>

# %%
WindData
# Out:
#                      Cup116m_Mean  Cup116m_Stdv  Cup116m_Min  Cup116m_Max  \
# name
# 2015-09-07 11:00:00       2.29737      0.436317     1.018530      3.19492
# 2015-09-07 11:10:00       2.33373      1.142690     0.540292      6.16171
# 2015-09-07 11:20:00       2.65680      0.516193     1.161560      4.43188
# 2015-09-07 11:30:00       2.19811      0.616147     0.622069      3.82984
# 2015-09-07 11:40:00       2.81388      0.951594     1.138440      7.15864
# ...                           ...           ...          ...          ...
# 2015-11-30 23:10:00      15.83240      1.187640    12.371700     19.12550
# 2015-11-30 23:20:00      18.25160      0.946480    15.250400     21.79970
# 2015-11-30 23:30:00      18.61920      0.916737    15.319600     20.95830
# 2015-11-30 23:40:00      18.91150      1.377910    14.111300     22.00390
# 2015-11-30 23:50:00      18.11510      1.130000    12.151000     21.38280
#
# ...

# %%
#Make 10 minute time-series plots of the different channels of mast data 
#(cups, sonic, temperature and vane) including mean, minimum and maximum. 

#mean speeds
plt.figure(figsize=(30,10))
plt.plot(WindData['Cup100m_Mean'], label = 'cup 100m')
plt.plot(WindData['Cup116m_Mean'], label = 'cup 116m')
plt.plot(WindData['Cup114m_Mean'], label = 'cup 114m')
plt.plot(WindData['Sonic100m_Vector_Mean'], label = 'sonic vector 100m')
plt.plot(WindData['Sonic100m_Scalar_Mean'], label = 'sonic scalar 100m')
plt.title('10 minute mean ws')
plt.legend()
plt.show()

# %%
#mean speeds
plt.figure(figsize=(50,10))
plt.plot(WindData['Cup100m_Mean'], label = 'mean')
plt.plot(WindData['Cup100m_Min'], label = 'min')
plt.plot(WindData['Cup100m_Max'], label = 'max')
plt.title('10 minute 100 ws')
plt.legend()
plt.show()

# %%
WindData
# Out:
#                      Cup116m_Mean  Cup116m_Stdv  Cup116m_Min  Cup116m_Max  \
# name
# 2015-09-07 11:00:00       2.29737      0.436317     1.018530      3.19492
# 2015-09-07 11:10:00       2.33373      1.142690     0.540292      6.16171
# 2015-09-07 11:20:00       2.65680      0.516193     1.161560      4.43188
# 2015-09-07 11:30:00       2.19811      0.616147     0.622069      3.82984
# 2015-09-07 11:40:00       2.81388      0.951594     1.138440      7.15864
# ...                           ...           ...          ...          ...
# 2015-11-30 23:10:00      15.83240      1.187640    12.371700     19.12550
# 2015-11-30 23:20:00      18.25160      0.946480    15.250400     21.79970
# 2015-11-30 23:30:00      18.61920      0.916737    15.319600     20.95830
# 2015-11-30 23:40:00      18.91150      1.377910    14.111300     22.00390
# 2015-11-30 23:50:00      18.11510      1.130000    12.151000     21.38280
#
# ...

# %%
WindData.columns
# Out:
# Index(['Cup116m_Mean', 'Cup116m_Stdv', 'Cup116m_Min', 'Cup116m_Max',
#        'Cup114m_Mean', 'Cup114m_Stdv', 'Cup114m_Min', 'Cup114m_Max',
#        'Cup100m_Mean', 'Cup100m_Stdv', 'Cup100m_Min', 'Cup100m_Max',
#        'Vane100m_Mean', 'Vane100m_Stdv', 'Vane100m_Min', 'Vane100m_Max',
#        'Temp100m_Mean', 'Temp100m_Stdv', 'Temp100m_Min', 'Temp100m_Max',
#        'Sonic100m_Scalar_Mean', 'Sonic100m_Scalar_Stdv',
#        'Sonic100m_Scalar_Min', 'Sonic100m_Scalar_Max', 'Sonic100m_Dir',
#        'Sonic100m_Vector_Mean', 'Spd', 'Spd_stdv', 'Spd_min', 'Spd_max', 'Dir',
#        'Dir_stdv', 'W', 'W_stdv', 'Available', 'CNR', 'Broad'],
#       dtype='object')

# %%
#mean speeds
plt.figure(figsize=(50,10))
plt.scatter(WindData.index, WindData['Cup100m_Mean'], label = 'mean')
plt.scatter(WindData.index, WindData['Cup100m_Min'], label = 'min')
plt.scatter(WindData.index, WindData['Cup100m_Max'], label = 'max')
plt.title('10 minute 100 ws')
plt.legend()
plt.show()

# %%
#mean speeds
plt.figure(figsize=(50,10))
plt.plot(WindData['Cup114m_Mean'], label = 'mean')
plt.plot(WindData['Cup114m_Min'], label = 'min')
plt.plot(WindData['Cup114m_Max'], label = 'max')
plt.title('10 minute 100 ws')
plt.legend()
plt.show()

# %%
#mean speeds
plt.figure(figsize=(50,10))
plt.plot(WindData['Cup116m_Mean'], label = 'mean')
plt.plot(WindData['Cup116m_Min'], label = 'min')
plt.plot(WindData['Cup116m_Max'], label = 'max')
plt.title('10 minute 100 ws')
plt.legend()
plt.show()
